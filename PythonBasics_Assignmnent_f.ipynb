# %% [markdown]
# ## Instructions :
# - Only Edit  *YOUR CODE HERE*
# - Do not change the assert statements which test your functions

# %% [markdown]
# Find the last element of a list. <br>
# Eg., l = [1, 2, 3, 4] <br>
# last_elemnt(l) -> 4

# %%
def last_element(l):
    """
    Input:
    l: Python list
    
    Output:
    last element of l
    """
    # YOUR CODE HERE
    if len(l)>0:
      return l[-1]

# %%
"""Testing code for last_element"""
assert last_element([1]) == 1
assert last_element(["Hello", "World"]) == "World"


print("Sample Tests passed", '\U0001F44D')
# Out:
# Sample Tests passed 👍

# %% [markdown]
# Find the number of elements in a list.<br>
# Eg., l = [1, 2, 3, 4] <br>
# num_elemnts(l) -> 4

# %%
def num_elements(l):
    """
    Input:
      l: Python list
    
    Output:
      number of elements in the list l
    """
    # YOUR CODE HERE
    return len(l)

# %%
"""Testing code for num_elements"""
assert num_elements([2, 3, 4])==3


print("Sample Tests passed", '\U0001F44D')
# Out:
# Sample Tests passed 👍

# %% [markdown]
# Reverse a list and return it. <br>
# Eg., l = [1, 2, 3, 4] <br>
# reverse_list(l) -> [4, 3, 2, 1]

# %%
def reverse_list(l):
    """
    Input:
      l: Python list

    Output:
      Python list with elements of l in reverse order
    """
    # YOUR CODE HERE
    if len(l)>0:
      return l[::-1]

# %%
"""Testing code for reverse_list"""
assert reverse_list([2, 3, 4])== [4, 3, 2]


print("Sample Tests passed", '\U0001F44D')
# Out:
# Sample Tests passed 👍

# %% [markdown]
# Find whether a list a palindrome -> a sequence that reads the same forwards and backwards <br>
# is_palindrome([1, 2, 1]) -> True <br>
# is_palindrome([1, 2, 3, 2, 1] -> True <br>
# is_palindrome([1, 2, 3, 1]) -> False

# %%
def is_palindrome(l):
    """
    Input:
      l: Python list
    
    Output:
      boolean value indicating whether l is a palindrome or not
    
    """
    # YOUR CODE HERE
    if l == l[::-1]:
      return True
    return False

# %%
"""Testing code for is_palindrome"""

assert(is_palindrome([1, 2, 1])) == True
assert(is_palindrome([1, 2, 3, 2, 1])) == True
assert(is_palindrome([1, 2, 3, 4])) == False

print("Sample Tests passed", '\U0001F44D')
# Out:
# Sample Tests passed 👍

# %% [markdown]
# Replace consecutive duplicate elements of list with single element. <br>
# Eg., l = [a, a, a, b, b, c, a, a, d, d, d, x, x] <br>
# compress(l) -> [a, b, c, a, d, x]

# %%
def compress(l):
    """
    Input:
      l: Python list
    Output:
      Returns a list with consecutive duplicate elements replaced by a single element
    """
    # YOUR CODE HERE
    new_l=l
    if len(l)>0:
      curr = l[0]
      new_l=[curr]
      for ele in l[1:]:
        if ele != curr:
          curr=ele
          new_l.append(curr)
    return new_l

# %%
"""Testing code for compress"""

assert(compress([1, 2, 2])) == [1, 2]
assert(compress([1, 2, 2, 2, 1, 1, 3, 'x', 'x', 'x'])) == [1, 2, 1, 3, 'x']


print("Sample Tests passed", '\U0001F44D')
# Out:
# Sample Tests passed 👍

# %% [markdown]
# Pack consecutive duplicates of list elements into sublists. <br>
# Eg., l = [1, 1, 1, 2, 2, 3, 3, 4]
# pack(l) -> [[1,1,1], [2,2], [3,3], [4]]

# %%
def pack(l):
    """
    Input:
      l: Python list
      
    Output:
      Returns a list with consecutive duplicate elements packed into sublists
    """
    # YOUR CODE HERE
    new_l=l
    if len(l)>0:
      curr = [l[0]]
      new_l=[]
      for ele in l[1:]:
        if ele == curr[0]:
          curr.append(ele)
        else:
          new_l.append(curr)
          curr=[ele]
      new_l.append(curr)
    return new_l

# %%
"""Testing code for pack"""
assert(pack([1, 1, 1, 2]) == [[1, 1, 1], [2]])
assert(pack([1, 1, 1, 2, 1, 1, 3, 3, 3])) == [[1, 1, 1], [2], [1, 1], [3, 3, 3]]

print("Sample Tests passed", '\U0001F44D')
# Out:
# Sample Tests passed 👍

# %% [markdown]
# Given two indices, i and k, the slice is the list containing the elements between the i'th and k'th element of the original list (left limit included). Start counting the elements with 0.
#
# Eg., l = [1, 3, 9, 8, 7];
# slice(l, 1, 3) --> [3, 9]

# %%
def slice(l, i, k):
    """
    Input:
      l: Python list
      i: start index of slice
      k: end index of slice (not included)
      
    Output:
      Returns a list containing the elements between i'th and k'th elements of original list l.
    """  
    # YOUR CODE HERE
    if len(l)>i:
       return l[i:k]
    return l

# %%
"""Testing code for slice"""
assert(slice([1, 3, 8, 9, 7], 1, 3)) == [3,8]
assert(slice([1, 4, 6, 'x', 9, 0], 2, 10)) == [6, 'x', 9, 0]


print("Sample Tests passed", '\U0001F44D')
# Out:
# Sample Tests passed 👍

# %% [markdown]
# Given a list l, index i and element elem, return a new list with elem at index i <br>
# Eg., l = [1, 3, 9, 8, 7]; <br>
# insert_element(l, 1, 3) --> [1, 3, 9, 1, 8, 7]

# %%
def insert_element(l, i, elem):
  """
  Input:
   l: Python list
   i: index at which to insert new element
   elem: new element to insert into l
  Ouput:
    a new list containing elem at index i. If i > len (l), insert element at the end of the list
  """  
  # YOUR CODE HERE
  if i>len(l):
    l.append(elem)
  else:
    l.insert(i,elem)
  return l

# %%
"""Testing code for insert_element"""
assert(insert_element([1, 2, 3, 4,], 2, 5)[2]) == 5
assert(insert_element([1, 5, ], 3, 5)) == [1, 5, 5]


print("Sample Tests passed", '\U0001F44D')
# Out:
# Sample Tests passed 👍

# %% [markdown]
#  Split a list into two parts; the length of the first part is given.
#  Do not use any predefined predicates.
#
#     Example:
#    split_list([a,b,c,d,e,f,g,h,i,k],3)-->>[a,b,c],[d,e,f,g,h,i,k] <br>
#    split_list([],5)-->[]

# %%
def split_list(l,k):
    """
    Input:
      l: python list
    k:
      Index at which to split l
    Output:
      single list if k > len(l)
      tuple of lists otherwise
    Returns splits list in the form of tuple. If k > len (l), return list as it is.
    """  
    # YOUR CODE HERE
    if len(l)<k:
      return l
    return l[:k],l[k:]

# %%
"""Testing code for split_list"""
assert(split_list([1, 2, 3, 4,], 2)) == ([1,2],[3,4])
assert(split_list([1, 5],3)) == [1,5]


print("Sample Tests passed", '\U0001F44D')
# Out:
# Sample Tests passed 👍

# %% [markdown]
#  Remove the K'th element from a list.
#  Example:
#  remove_at([a,b,c,d],2)-->[a,c,d]
#  <br> remove_at([a,b,c,[a,b,c],c,d],10)-->[a,b,c,[a,b,c],c]

# %%
def remove_elem(l,k):
    """
    Input:
      l: Python list
      k: remove element at index k
    
    Ouput:
      list with element at index k removed
    """  
    # YOUR CODE HERE
    if k>=len(l):
      return l[:-1]
    else:
      return l[:k-1:]+l[k::]

# %%
"""Testing code for remove kth elem"""
assert(remove_elem([1, 2, 3, 4,], 2)) ==[1,3,4]
assert(remove_elem([1, 5],3)) == [1]


print("Sample Tests passed", '\U0001F44D')
# Out:
# Sample Tests passed 👍

# %% [markdown]
#   Flatten a nested list structure.
#   Transform a list, possibly holding lists as elements into a `flat' list by replacing each
#   list with its elements (recursion)
#    Example:
#     def my_flatten([a, [b, [c, d], e]])-->[a, b, c, d, e]

# %%
def my_flatten(l):
  """
  Input: python list
  Output:
    python list with nested lists flattened
  """
  # YOUR CODE HERE
  
  flat_list = []
  for ele in l:
    if type(ele) == list:
      ele=my_flatten(ele)
      flat_list.extend(ele)
    else:
      flat_list.append(ele)
  return flat_list

# %%
"""Testing code for flatten list"""
assert(my_flatten([1, 2, 3, 4,[]])) ==[1,2,3,4]
assert(my_flatten([1, 2,[3,4]])) == [1,2,3,4]


print("Sample Tests passed", '\U0001F44D')
# Out:
# Sample Tests passed 👍

# %% [markdown]
#  Rotate a list N places to the left.
#  Examples:<br>
#   rotate_list([a,b,c,d,e,f,g,h],3)--> [d,e,f,g,h,a,b,c]
#    <br> rotate_list([a,b,c,d,e,f,g,h],-2)--> [g,h,a,b,c,d,e,f]

# %%
def rotate_list(l,N):
  """
 Input:
   l: Python list
   N: number of indices by which to rotate the list
 Ouput:
   python list which is l rotated to the left by n places
 """
  # YOUR CODE HERE
  if N>len(l):
    return l
  else:
    return l[N:]+l[:N]

# %%
"""Testing code for rotate list from N index list"""
assert(rotate_list([1, 2, 3, 4],2)) ==[3,4,1,2]
assert(rotate_list(['a','b','c','d','e','f'],10)) == ['a','b','c','d','e','f']


print("Sample Tests passed", '\U0001F44D')
# Out:
# Sample Tests passed 👍

# %% [markdown]
#  Sorting a list of lists according to length of sublists<br>
#  We suppose that a list (InList) contains elements that are lists themselves.<br> The objective   is to sort the elements of InList according to their length.<br>
#  Example:
#     def sort_list([[a,b,c],[d,e],[f,g,h],[d,e],[i,j,k,l],[m,n],[o]],L)--> [[o], [d, e], [d, e], [m, n], [a, b, c], [f, g, h], [i, j, k, l]]

# %%
def sort_list(l):
 # YOUR CODE HERE
 for i in range(len(l)-1):
    for j in range(len(l)-i-1):
      if len(l[j])>len(l[j+1]):
        temp=l[j]
        l[j]=l[j+1]
        l[j+1]=temp
 return l

# %%
"""Testing code for rotate list from N index list"""
assert(sort_list([[1, 2, 3], [4]])) ==[[4],[1,2,3]]
assert(sort_list([['a','b'],['c'],['d','e','f']])) == [['c'],['a','b'],['d','e','f']]


print("Sample Tests passed", '\U0001F44D')
# Out:
# Sample Tests passed 👍

# %% [markdown]
#  Determine whether a given integer number is prime.
#  Example:<br>
# is_prime(7)-->True<br>
# is_prime(10)-->False

# %%
def is_prime(n):
  """
 Input:
  n: int 
 Output:
  bool indicating whether n is prime
 """
 # YOUR CODE HERE
  if n==0 or n==1:
    return False
  if n==2:
    return True
  for i in range(2,int(n/2) +1):
    if n%i==0:
      return False
  return True

# %%
"""Testing for prime number"""
assert(is_prime(8)) == False
assert(is_prime(7)) == True

print("Sample Tests passed", '\U0001F44D')
# Out:
# Sample Tests passed 👍

# %% [markdown]
#   Determine the greatest common divisor of two positive integer numbers.
#   Use Euclid's algorithm.<br>
#   Example:<br>
#  gcd(36, 63)-->9

# %%
def gcd(a,b):
    """
    Input:
      a, b: ints
    Output:
      int which is the gcd of a, b
    """
    # YOUR CODE HERE
    if a > b: 
        s = a 
    else: 
        s = b 
    for i in range(1, s+1): 
        if((a % i == 0) and (b % i == 0)): 
            gcd = i 
    return gcd

# %%
"""Testing for gcd of two numbers"""
assert(gcd(8,2)) == 2
assert(gcd(7,0)) == 7

print("Sample Tests passed", '\U0001F44D')
# Out:
# Sample Tests passed 👍

# %% [markdown]
#  Determine the prime factors of a given positive integer<br>
#  Construct a flat list containing the prime factors in ascending order.
#  Example:<br>
#   prime_factors(315)--> [3,3,5,7]

# %%
import math
def prime_factors(n):
 """
 Input:
  n: int
 Output:
  List containing prime factors of n in sorted order
 """ 
 # YOUR CODE HERE
 l=[]
 while n % 2 == 0: 
       l.append(2)
       n = n / 2
 for i in range(3,int(math.sqrt(n))+1,2):
    while n % i== 0:
      l.append(i)
      n = n / i 
 if n>2:
  l.append(n)
 return sorted(l)

# %%
"""Testing for prime factor of a number """
assert(prime_factors(12)) == [2,2,3]

print("Sample Tests passed", '\U0001F44D')
# Out:
# Sample Tests passed 👍

# %% [markdown]
#  Write a Python script to add a key to a dictionary.<br>
#  add_item({0: 10, 1: 20},2,30)-->{{0: 10, 1: 20, 2: 30}

# %%
def add_item(d,key,value):
 """
 Input:
  d: python dictionary
  key: any python object
  value: any python object
 Output:
  new dictionary with a new (key, value) pair in it
 """
 # YOUR CODE HERE
 d[key]=value
 return d

# %%
"""Testing for add element in a dictionary """
assert(add_item({'a':'akshay'},'m','mainsh'))=={'a': 'akshay', 'm': 'mainsh'}

print("Sample Tests passed", '\U0001F44D')
# Out:
# Sample Tests passed 👍

# %% [markdown]
# Write a Python script to concatenate  dictionaries to create a new one.<br>
# example:<br>
# dic1={1:10, 2:20}<br>
# dic2={3:30, 4:40}<br>
# dic3={5:50,6:60}<br>
# <br>def dict_concatenate(dict1,dict2,dict3)--> {1: 10, 2: 20, 3: 30, 4: 40, 5: 50, 6: 60}

# %%
def dict_concatenate(d1,d2,d3):
 '''
 Input:
  d1, d2, d3: python dictionaries
 Output:
  dictionary containing all key, value pairs from d1, d2, d3
 '''
 r_dict={}
 # YOUR CODE HERE
 r_dict.update(d1)
 r_dict.update(d2)
 r_dict.update(d3)
 return r_dict

# %%
"""Testing for concatenation of dictionaries """
assert(dict_concatenate({1:10,2:20},{3:30,4:40},{}))=={1:10,2:20,3:30,4:40}
assert(dict_concatenate({'a':'aaa','b':'bbb'},{'c':'ccc','d':'ddd'},{})['c'])=='ccc'
print("Sample Tests passed", '\U0001F44D')
# Out:
# Sample Tests passed 👍

# %% [markdown]
# Write a Python program to check if a given key already exists in a dictionary.<br>
# example-<br>
# check_key({1:10,2:20,3:30},2)--> True

# %%
def check_key(d,key):
 """
  Input:
    d: python dictionary
    key: python object
  Output:
    boolean value indicating whether key is present in d
 """
 # YOUR CODE HERE
 if key in d.keys():
  return True
 return False

# %%
"""Tests for check_key"""
assert check_key({1:10, 2:30, 3:40}, 2) == True
print("Sample Tests passed", '\U0001F44D')
# Out:
# Sample Tests passed 👍

# %% [markdown]
# Write a Python program to check a dictionary is empty or not.<br>
# example-<br>
# is_empty({})--> True<br>
# is_empty({'a':'b','c':'d'})--> False

# %%
def is_empty(d):
 """
 Input:
  d: python dictionary
 Output:
  bool value indicating whether the dictionary is empty
 """ 
 # YOUR CODE HERE
 return not bool(d)

# %%
"""Test for is_empty"""
assert is_empty({}) == True
assert is_empty({1:10}) == False
print("Sample Tests passed", '\U0001F44D')
# Out:
# Sample Tests passed 👍

# %% [markdown]
# Write a Python program to combine two dictionary adding values for common keys.<br>
# d1 = {'a': 100, 'b': 200, 'c':300}<br>
# d2 = {'a': 300, 'b': 200, 'd':400}<br>Example-<br>
# combine_duplicates(d1,d2)-->>({'a': 400, 'b': 400, 'd': 400, 'c': 300})

# %%
def combine_duplicates(d1,d2):
 """
 Input:
  d1, d2 : Python dictionaries
 Outpu:
  Dictionary concatenating (key, value) pairs of d1, d2 and adding values of common keys
 """
 # YOUR CODE HERE
 for key in d2: 
  if key in d1: 
    d2[key]=d2[key]+d1[key]
 for key in d1:
  if key not in d2:
    d2[key]=d1[key]
 return d2

# %%
"""Test for combine_duplicates"""
assert combine_duplicates({'a':10, 'b':20}, {'a':50, 'c':20}) == {'a':60, 'b':20, 'c':20}
print("Sample Tests passed", '\U0001F44D')
# Out:
# Sample Tests passed 👍

# %% [markdown]
# Write a Python program to find the highest n values in a dictionary.<br>
# Example-<br>
# max_3({'a':500, 'b':5874, 'c': 560,'d':400, 'e':5000, 'f': 20}-->[5874,5000,500]

# %%
def max_n(d,n):
  """
  Input:
    d: python dictionary
    n: int indicating number of highest values to return from d
  Output:
    list of length n containing highest n values of d. 
    (return all values if number of values in d is less than n)
  """
  # YOUR CODE HERE
  max_list=list(d.values())
  max_list.sort(reverse=True)
  return max_list[:n]

# %%
"""Test for max_n """
assert max_n({'a':500, 'b':5874, 'c': 560,'d':400, 'e':5000, 'f': 20},2) == [5874, 5000]
print("Sample Tests passed", '\U0001F44D')
# Out:
# Sample Tests passed 👍
